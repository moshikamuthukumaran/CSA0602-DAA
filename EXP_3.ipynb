# %% [markdown]
# <a href="https://colab.research.google.com/github/moshikamuthukumaran/CSA0602-DAA/blob/main/EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXP 3

# %%
def rec(n):
    if n==0:return 1
    return n*rec(n-1)

n=5
f=1
for i in range(1,n+1):f*=i
print("Iterative:",f)
print("Recursive:",rec(n))
# Out:
# Iterative: 120
# Recursive: 120
