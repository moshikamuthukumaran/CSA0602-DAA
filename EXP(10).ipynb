# %% [markdown]
# <a href="https://colab.research.google.com/github/moshikamuthukumaran/CSA0602-DAA/blob/main/EXP_(10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXP 10

# %%
a=[12,11,13,5,6]

for i in range(1,len(a)):
    x=a[i]
    j=i-1
    while j>=0 and a[j]>x:
        a[j+1]=a[j]
        j-=1
    a[j+1]=x

print(a)
# Out:
# [5, 6, 11, 12, 13]
