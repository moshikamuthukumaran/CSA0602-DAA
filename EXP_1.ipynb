# %% [markdown]
# <a href="https://colab.research.google.com/github/moshikamuthukumaran/CSA0602-DAA/blob/main/EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXP 1

# %%
arr = [10, 25, 30, 45, 50]
key = 30

for i in range(len(arr)):
    if arr[i] == key:
        print("Key found at index", i)
        break
else:
    print("Key not found")
# Out:
# Key found at index 2
