# %% [markdown]
# <a href="https://colab.research.google.com/github/moshikamuthukumaran/CSA0602-DAA/blob/main/EXP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXP 4

# %%
def fib(n):
    if n<=1:return n
    return fib(n-1)+fib(n-2)

n=6
a=[fib(i) for i in range(n)]
print(a)
# Out:
# [0, 1, 1, 2, 3, 5]
