# %% [markdown]
# <a href="https://colab.research.google.com/github/moshikamuthukumaran/CSA0602-DAA/blob/main/EXP_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXP 7

# %%
def quick(a):
    if len(a)<=1:return a
    p=a[0]
    return quick([x for x in a[1:] if x<p])+[p]+quick([x for x in a[1:] if x>=p])

print(quick([10,7,8,9,1,5]))
# Out:
# [1, 5, 7, 8, 9, 10]
